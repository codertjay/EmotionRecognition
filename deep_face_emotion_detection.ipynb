# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace ## pip install deepface
# Out:
# Directory  C:\Users\Codertjay /.deepface created
# Directory  C:\Users\Codertjay /.deepface/weights created

# %%
img =cv2.imread("sad_boy.jpg")

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\Codertjay\.deepface\weights\facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:09<00:00, 601kB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\Codertjay\.deepface\weights\age_model_weights.h5
#  37%|███▋      | 198M/539M [05:40<18:19, 310kB/s]

# %% [markdown]
# ## We are trying to draw rectangle accross the face
